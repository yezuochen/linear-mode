# %%
from sklearn.linear_model import LinearRegression

# %%
from yellowbrick.regressor import CooksDistance
from yellowbrick.datasets import load_concrete

# Load the regression dataset
X, y = load_concrete()
print(X)
# Instantiate and fit the visualizer
visualizer = CooksDistance()
visualizer.fit(X, y)
visualizer.show()
# Out:
#       cement   slag    ash  water  splast  coarse   fine  age
# 0      540.0    0.0    0.0  162.0     2.5  1040.0  676.0   28
# 1      540.0    0.0    0.0  162.0     2.5  1055.0  676.0   28
# 2      332.5  142.5    0.0  228.0     0.0   932.0  594.0  270
# 3      332.5  142.5    0.0  228.0     0.0   932.0  594.0  365
# 4      198.6  132.4    0.0  192.0     0.0   978.4  825.5  360
# ...      ...    ...    ...    ...     ...     ...    ...  ...
# 1025   276.4  116.0   90.3  179.6     8.9   870.1  768.3   28
# 1026   322.2    0.0  115.6  196.0    10.4   817.9  813.4   28
# 1027   148.5  139.4  108.6  192.7     6.1   892.4  780.0   28
# 1028   159.1  186.7    0.0  175.6    11.3   989.6  788.9   28
# 1029   260.9  100.5   78.3  200.6     8.6   864.5  761.5   28
#
# [1030 rows x 8 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 2 line 9
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=6'>7</a> # Instantiate and fit the visualizer
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=7'>8</a> visualizer = CooksDistance()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=8'>9</a> visualizer.fit(X, y)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=9'>10</a> visualizer.show()
#
# File c:\Users\zuoch\AppData\Local\Programs\Python\Python311\Lib\site-packages\yellowbrick\regressor\influence.py:173, in CooksDistance.fit(self, X, y)
#     168 self.outlier_percentage_ = (
#     169     sum(self.distance_ > self.influence_threshold_) / X.shape[0]
#     170 )
#     171 self.outlier_percentage_ *= 100.0
# --> 173 self.draw()
#     174 return self
#
# File c:\Users\zuoch\AppData\Local\Programs\Python\Python311\Lib\site-packages\yellowbrick\regressor\influence.py:182, in CooksDistance.draw(self)
#     177 """
#     178 Draws a stem plot where each stem is the Cook's Distance of the instance at the
#     179 index specified by the x axis. Optionaly draws a threshold line.
#     180 """
#     181 # Draw a stem plot with the influence for each instance
# --> 182 _, _, baseline = self.ax.stem(
#     183     self.distance_, linefmt=self.linefmt, markerfmt=self.markerfmt,
#     184     use_line_collection=True
#     185 )
#     187 # No padding on either side of the instance index
#     188 self.ax.set_xlim(0, len(self.distance_))
#
# File c:\Users\zuoch\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# TypeError: Axes.stem() got an unexpected keyword argument 'use_line_collection'

# %%
from sklearn.linear_model import LinearRegression
from yellowbrick.regressor import ResidualsPlot

# Instantiate and fit the visualizer
model = LinearRegression()
visualizer_residuals = ResidualsPlot(model)
visualizer_residuals.fit(X, y)
visualizer_residuals.show()
# Out:
# <Axes: title={'center': 'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
i_less_influential = (visualizer.distance_ <= visualizer.influence_threshold_)
X_li, y_li = X[i_less_influential], y[i_less_influential]

model = LinearRegression()
visualizer_residuals = ResidualsPlot(model)
visualizer_residuals.fit(X_li, y_li)
visualizer_residuals.show()
# Out:
# <Axes: title={'center': 'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
from yellowbrick.datasets import load_concrete
from yellowbrick.regressor import cooks_distance

# Load the regression dataset
X, y = load_concrete()

# Instantiate and fit the visualizer
cooks_distance(
    X, y,
    draw_threshold=True,
    linefmt="C0-", markerfmt=","
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 4 line 8
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W3sdW50aXRsZWQ%3D?line=4'>5</a> X, y = load_concrete()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W3sdW50aXRsZWQ%3D?line=6'>7</a> # Instantiate and fit the visualizer
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W3sdW50aXRsZWQ%3D?line=7'>8</a> cooks_distance(
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W3sdW50aXRsZWQ%3D?line=8'>9</a>     X, y,
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W3sdW50aXRsZWQ%3D?line=9'>10</a>     draw_threshold=True,
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W3sdW50aXRsZWQ%3D?line=10'>11</a>     linefmt="C0-", markerfmt=","
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W3sdW50aXRsZWQ%3D?line=11'>12</a> )
#
# File c:\Users\zuoch\AppData\Local\Programs\Python\Python311\Lib\site-packages\yellowbrick\regressor\influence.py:293, in cooks_distance(X, y, ax, draw_threshold, linefmt, markerfmt, show, **kwargs)
#     229 """
#     230 Cook's Distance is a measure of how influential an instance is to the computation of
#     231 a regression, e.g. if the instance is removed would the estimated coeficients of the
#    (...)
#     284     visualization (e.g. size or title parameters).
#     285 """
#     286 viz = CooksDistance(
#     287     ax=ax,
#     288     draw_threshold=draw_threshold,
#    (...)
#     291     **kwargs
#     292 )
# --> 293 viz.fit(X, y)
#     295 # Draw the final visualization
#     296 if show:
#
# File c:\Users\zuoch\AppData\Local\Programs\Python\Python311\Lib\site-packages\yellowbrick\regressor\influence.py:173, in CooksDistance.fit(self, X, y)
#     168 self.outlier_percentage_ = (
#     169     sum(self.distance_ > self.influence_threshold_) / X.shape[0]
#     170 )
#     171 self.outlier_percentage_ *= 100.0
# --> 173 self.draw()
#     174 return self
#
# File c:\Users\zuoch\AppData\Local\Programs\Python\Python311\Lib\site-packages\yellowbrick\regressor\influence.py:182, in CooksDistance.draw(self)
#     177 """
#     178 Draws a stem plot where each stem is the Cook's Distance of the instance at the
#     179 index specified by the x axis. Optionaly draws a threshold line.
#     180 """
#     181 # Draw a stem plot with the influence for each instance
# --> 182 _, _, baseline = self.ax.stem(
#     183     self.distance_, linefmt=self.linefmt, markerfmt=self.markerfmt,
#     184     use_line_collection=True
#     185 )
#     187 # No padding on either side of the instance index
#     188 self.ax.set_xlim(0, len(self.distance_))
#
# File c:\Users\zuoch\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# TypeError: Axes.stem() got an unexpected keyword argument 'use_line_collection'
